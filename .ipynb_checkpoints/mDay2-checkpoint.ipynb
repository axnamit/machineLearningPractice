# %%
import pandas as pd

# %%
readCsv=pd.read_csv("C:/Users/amit/Downloads/cars.csv",index_col=0)

# %%
readCsv.to_html("C:/Users/amit/Downloads/cars.html")

# %%
df=pd.DataFrame(readCsv)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
import numpy as np

# %%
aa=np.array(df)

# %%
aa
# Out:
# array([], shape=(407, 0), dtype=float64)

# %%
print(aa)
# Out:
# []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
readCsv=pd.read_csv("C:/Users/amit/Downloads/cars.csv")

# %%
readCsv
# Out:
#     Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0    STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1    Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2    Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3    Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4    AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US
# 5      Ford Torino;17.0;8;302.0;140.0;3449.;10.5;70;US
# 6    Ford Galaxie 500;15.0;8;429.0;198.0;4341.;10.0...
# 7    Chevrolet Impala;14.0;8;454.0;220.0;4354.;9.0;...
# 8    Plymouth Fury iii;14.0;8;440.0;215.0;4312.;8.5...
# 9    Pontiac Catalina;14.0;8;455.0;225.0;4425.;10.0...
# 10   AMC Ambassador DPL;15.0;8;390.0;190.0;3850.;8....
# 11   Citroen DS-21 Pallas;0;4;133.0;115.0;3090.;17....
# 12   Chevrolet Chevelle Concours (sw);0;8;350.0;165...
# 13   Ford Torino (sw);0;8;351.0;153.0;4034.;11.0;70;US
# 14   Plymouth Satellite (sw);0;8;383.0;175.0;4166.;...
# 15   AMC Rebel SST (sw);0;8;360.0;175.0;3850.;11.0;...
# ...

# %%
aa=np.array(readCsv)

# %%
aa
# Out:
# array([['STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;INT;CAT'],
#        ['Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3504.;12.0;70;US'],
#        ['Buick Skylark 320;15.0;8;350.0;165.0;3693.;11.5;70;US'],
#        ['Plymouth Satellite;18.0;8;318.0;150.0;3436.;11.0;70;US'],
#        ['AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US'],
#        ['Ford Torino;17.0;8;302.0;140.0;3449.;10.5;70;US'],
#        ['Ford Galaxie 500;15.0;8;429.0;198.0;4341.;10.0;70;US'],
#        ['Chevrolet Impala;14.0;8;454.0;220.0;4354.;9.0;70;US'],
#        ['Plymouth Fury iii;14.0;8;440.0;215.0;4312.;8.5;70;US'],
#        ['Pontiac Catalina;14.0;8;455.0;225.0;4425.;10.0;70;US'],
#        ['AMC Ambassador DPL;15.0;8;390.0;190.0;3850.;8.5;70;US'],
#        ['Citroen DS-21 Pallas;0;4;133.0;115.0;3090.;17.5;70;Europe'],
#        ['Chevrolet Chevelle Concours (sw);0;8;350.0;165.0;4142.;11.5;70;US'],
#        ['Ford Torino (sw);0;8;351.0;153.0;4034.;11.0;70;US'],
# ...

# %%
print(type(aa))
# Out:
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
style.use('fivethirtyeight')

# %%
readCsv=pd.read_csv("C:/Users/amit/Downloads/cars.csv",index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2df25db97a5b> in <module>
# ----> 1 readCsv=pd.read_csv("C:/Users/amit/Downloads/cars.csv",index_col=0)
#
# NameError: name 'pd' is not defined

# %%
df=readCsv.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-943bbde4370c> in <module>
# ----> 1 df=readCsv.head(5)
#
# NameError: name 'readCsv' is not defined

# %%
df2=df.set_index('hh',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5392a4e0d597> in <module>
# ----> 1 df2=df.set_index('hh',inplace=True)
#
# NameError: name 'df' is not defined
